# %% [markdown]
# # SQLite demo (chinook database)
#
# This is a little demo of using SQL and Python to query a simple SQLite database. The example database being used here is called "chinook" and was taken from https://www.sqlitetutorial.net/sqlite-sample-database/, which contains information about an iTunes-like commerce site.

# %%
import sqlite3
import pandas as pd

# source: https://www.sqlitetutorial.net/sqlite-sample-database/
conn = sqlite3.connect('chinook.db')

# %%
# helper function to run queries in SQL files
def run_query_from_file(filename):
    with open(filename, 'r') as file:
        queries = file.read()
    # if there are multiple queries in the file, run the first one
    queries = queries.split(';')
    return pd.read_sql_query(queries[0], conn)

# %% [markdown]
# ## Customer sales by support rep
#
# I chose to include the people who don't have the role "Sales Support Agent" because I think doing so is a good confirmation that no one else does any support work.

# %%
run_query_from_file('sales_by_emp.sql').sort_values('SalesTotal', ascending=False)
# Out:
#    EmployeeId FirstName  LastName                Title  CustomersSupported  \
# 2           3      Jane   Peacock  Sales Support Agent                  21
# 3           4  Margaret      Park  Sales Support Agent                  20
# 4           5     Steve   Johnson  Sales Support Agent                  18
# 0           1    Andrew     Adams      General Manager                   0
# 1           2     Nancy   Edwards        Sales Manager                   0
# 5           6   Michael  Mitchell           IT Manager                   0
# 6           7    Robert      King             IT Staff                   0
# 7           8     Laura  Callahan             IT Staff                   0
#
#    SalesTotal
# 2      833.04
# 3      775.40
# 4      720.16
# 0        0.00
# 1        0.00
# 5        0.00
# 6        0.00
# 7        0.00

# %% [markdown]
# ## Top 10 artists by revenue

# %%
run_query_from_file('sales_by_artist.sql').head(10)
# Out:
#                     Artist  Quantity  Revenue
# 0              Iron Maiden       140   138.60
# 1                       U2       107   105.93
# 2                Metallica        91    90.09
# 3             Led Zeppelin        87    86.13
# 4                     Lost        41    81.59
# 5               The Office        25    49.75
# 6  Os Paralamas Do Sucesso        45    44.55
# 7              Deep Purple        44    43.56
# 8            Faith No More        42    41.58
# 9             Eric Clapton        40    39.60

# %% [markdown]
# ## Sales by country

# %%
run_query_from_file('sales_by_country.sql')
# Out:
#            Country  Revenue  Customers
# 0              USA   523.06         13
# 1           Canada   303.96          8
# 2           France   195.10          5
# 3           Brazil   190.10          5
# 4          Germany   156.48          4
# 5   United Kingdom   112.86          3
# 6   Czech Republic    90.24          2
# 7         Portugal    77.24          2
# 8            India    75.26          2
# 9            Chile    46.62          1
# 10         Ireland    45.62          1
# 11         Hungary    45.62          1
# 12         Austria    42.62          1
# 13         Finland    41.62          1
# 14     Netherlands    40.62          1
# 15          Norway    39.62          1
# 16          Sweden    38.62          1
# 17          Poland    37.62          1
# 18           Italy    37.62          1
# 19         Denmark    37.62          1
# 20       Australia    37.62          1
# 21       Argentina    37.62          1
# 22           Spain    37.62          1
# 23         Belgium    37.62          1

# %% [markdown]
# ## Sales by genre

# %%
run_query_from_file('sales_by_genre.sql')
# Out:
#                  Genre  Quantity  Revenue
# 0                 Rock       835   826.65
# 1                Latin       386   382.14
# 2                Metal       264   261.36
# 3   Alternative & Punk       244   241.56
# 4             TV Shows        47    93.53
# 5                 Jazz        80    79.20
# 6                Blues        61    60.39
# 7                Drama        29    57.71
# 8             R&B/Soul        41    40.59
# 9            Classical        41    40.59
# 10    Sci Fi & Fantasy        20    39.80
# 11              Reggae        30    29.70
# 12                 Pop        28    27.72
# 13          Soundtrack        20    19.80
# 14              Comedy         9    17.91
# 15         Hip Hop/Rap        17    16.83
# 16          Bossa Nova        15    14.85
# 17         Alternative        14    13.86
# 18               World        13    12.87
# 19     Science Fiction         6    11.94
# 20         Heavy Metal        12    11.88
# 21   Electronica/Dance        12    11.88
# 22      Easy Listening        10     9.90
# 23       Rock And Roll         6     5.94

# %% [markdown]
# ## Top 25 albums by revenue

# %%
# top 25 albums
# now let's do this using pandas instead of SQL

# pull all the tables we need into dataframes
df_inv_itms = pd.read_sql_query('select * from invoice_items', conn)
df_tracks = pd.read_sql_query('select * from tracks', conn)
df_albums = pd.read_sql_query('select * from albums', conn)
df_artists = pd.read_sql_query('select * from artists', conn)

# merge track and album info
df_sales_by_album = df_tracks.merge(df_albums, how='left', on='AlbumId')

# merge invoice items with track/album info
df_sales_by_album = df_inv_itms.merge(df_sales_by_album, how='left', on='TrackId')

# merge on artist info
df_sales_by_album = df_sales_by_album.merge(df_artists, how='left', on='ArtistId')

# clean it up a bit
df_sales_by_album = df_sales_by_album[['InvoiceLineId', 'UnitPrice_x', 'Quantity', 'Name_x', 'Title', 'Name_y']]
df_sales_by_album = df_sales_by_album.rename(columns={'UnitPrice_x':'UnitPrice',
                                    'Name_x': 'TrackName',
                                    'Title':'AlbumName',
                                    'Name_y': 'ArtistName'
                                   })
df_sales_by_album['Revenue'] = df_sales_by_album['Quantity'] * df_sales_by_album['UnitPrice']

# sum quantity and revenue by album/artist
df_sales_by_album = df_sales_by_album.groupby(
    ['AlbumName', 'ArtistName']
    )[['Quantity', 'Revenue']].sum().sort_values('Revenue', ascending=False).reset_index()
df_sales_by_album = df_sales_by_album.rename(columns={'Quantity':'QuantityTracksPurchased'})

df_sales_by_album.head(25)
# Out:
#                                             AlbumName  \
# 0            Battlestar Galactica (Classic), Season 1
# 1                                The Office, Season 3
# 2                                      Minha Historia
# 3                                    Heroes, Season 1
# 4                                      Lost, Season 2
# 5                                       Greatest Hits
# 6                                           Unplugged
# 7                      Battlestar Galactica, Season 3
# 8                                      Lost, Season 3
# 9                                            Acústico
# 10                                     Lost, Season 1
# 11                                      Greatest Kiss
# 12                                  Chronicle, Vol. 2
# 13           My Generation - The Very Best Of The Who
# 14                                       Prenda Minha
# 15                                       Acústico MTV
# 16                                  Chronicle, Vol. 1
# 17                            International Superhits
# 18                                        Up An' Atom
# 19                                     Rattle And Hum
# 20                                Use Your Illusion I
# 21                  The Best Of R.E.M.: The IRS Years
# 22                                     Afrociberdelia
# 23  Instant Karma: The Amnesty International Campa...
# 24                                     American Idiot
#
#                         ArtistName  QuantityTracksPurchased  Revenue
# 0   Battlestar Galactica (Classic)                       18    35.82
# 1                       The Office                       16    31.84
# 2                    Chico Buarque                       27    26.73
# 3                           Heroes                       13    25.87
# 4                             Lost                       13    25.87
# 5                    Lenny Kravitz                       26    25.74
# 6                     Eric Clapton                       25    24.75
# 7             Battlestar Galactica                       12    23.88
# 8                             Lost                       11    21.89
# 9                            Titãs                       22    21.78
# 10                            Lost                       10    19.90
# 11                            Kiss                       20    19.80
# 12    Creedence Clearwater Revival                       19    18.81
# 13                         The Who                       19    18.81
# 14                  Caetano Veloso                       19    18.81
# 15         Os Paralamas Do Sucesso                       18    17.82
# 16    Creedence Clearwater Revival                       18    17.82
# 17                       Green Day                       18    17.82
# 18                      Gene Krupa                       17    16.83
# 19                              U2                       17    16.83
# 20                   Guns N' Roses                       17    16.83
# 21                          R.E.M.                       17    16.83
# 22     Chico Science & Nação Zumbi                       16    15.84
# 23                              U2                       16    15.84
# 24                       Green Day                       15    14.85

# %%
# conn.close()
