# %%
import sqlite3
import pandas as pd

# source: https://www.sqlitetutorial.net/sqlite-sample-database/
conn = sqlite3.connect('chinook.db')
cursor = conn.cursor()

# %%
def run_query_from_file(filename):
    with open(filename, 'r') as file:
        queries = file.read()
    # if there are multiple queries in the file, run the first one
    queries = queries.split(';')
    return pd.read_sql_query(queries[0], conn)

# %%
# most lucrative salespeople
run_query_from_file('sales_by_emp.sql').sort_values('SalesTotal', ascending=False)
# Out:
#    EmployeeId FirstName  LastName                Title  CustomersSupported  \
# 2           3      Jane   Peacock  Sales Support Agent                  21
# 3           4  Margaret      Park  Sales Support Agent                  20
# 4           5     Steve   Johnson  Sales Support Agent                  18
# 0           1    Andrew     Adams      General Manager                   0
# 1           2     Nancy   Edwards        Sales Manager                   0
# 5           6   Michael  Mitchell           IT Manager                   0
# 6           7    Robert      King             IT Staff                   0
# 7           8     Laura  Callahan             IT Staff                   0
#
#    SalesTotal
# 2      833.04
# 3      775.40
# 4      720.16
# 0        0.00
# 1        0.00
# 5        0.00
# 6        0.00
# 7        0.00

# %%
# top 10 selling artists
run_query_from_file('sales_by_artist.sql').loc[:9]
# Out:
#                       Name  Quantity  Revenue
# 0              Iron Maiden       140   138.60
# 1                       U2       107   105.93
# 2                Metallica        91    90.09
# 3             Led Zeppelin        87    86.13
# 4  Os Paralamas Do Sucesso        45    44.55
# 5              Deep Purple        44    43.56
# 6            Faith No More        42    41.58
# 7                     Lost        41    81.59
# 8             Eric Clapton        40    39.60
# 9                   R.E.M.        39    38.61

# %%
# countries by sales
run_query_from_file('sales_by_country.sql')
# Out:
#            Country  Revenue  Customers
# 0              USA   523.06         13
# 1           Canada   303.96          8
# 2           France   195.10          5
# 3           Brazil   190.10          5
# 4          Germany   156.48          4
# 5   United Kingdom   112.86          3
# 6   Czech Republic    90.24          2
# 7         Portugal    77.24          2
# 8            India    75.26          2
# 9            Chile    46.62          1
# 10         Ireland    45.62          1
# 11         Hungary    45.62          1
# 12         Austria    42.62          1
# 13         Finland    41.62          1
# 14     Netherlands    40.62          1
# 15          Norway    39.62          1
# 16          Sweden    38.62          1
# 17          Poland    37.62          1
# 18           Italy    37.62          1
# 19         Denmark    37.62          1
# 20       Australia    37.62          1
# 21       Argentina    37.62          1
# 22           Spain    37.62          1
# 23         Belgium    37.62          1

# %%
run_query_from_file('sales_by_genre.sql')
# Out:
#                   Name  Quantity  Revenue
# 0                 Rock       835   826.65
# 1                Latin       386   382.14
# 2                Metal       264   261.36
# 3   Alternative & Punk       244   241.56
# 4                 Jazz        80    79.20
# 5                Blues        61    60.39
# 6             TV Shows        47    93.53
# 7             R&B/Soul        41    40.59
# 8            Classical        41    40.59
# 9               Reggae        30    29.70
# 10               Drama        29    57.71
# 11                 Pop        28    27.72
# 12          Soundtrack        20    19.80
# 13    Sci Fi & Fantasy        20    39.80
# 14         Hip Hop/Rap        17    16.83
# 15          Bossa Nova        15    14.85
# 16         Alternative        14    13.86
# 17               World        13    12.87
# 18         Heavy Metal        12    11.88
# 19   Electronica/Dance        12    11.88
# 20      Easy Listening        10     9.90
# 21              Comedy         9    17.91
# 22     Science Fiction         6    11.94
# 23       Rock And Roll         6     5.94

# %%
# cursor.close()
# conn.close()
